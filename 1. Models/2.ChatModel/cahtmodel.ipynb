# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

chatmodel = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    max_completion_tokens=100
)

response = chatmodel.invoke("Tell about the history of AI")
print(response.content)
# Out:
# The history of artificial intelligence (AI) is a fascinating journey that spans several decades, marked by periods of optimism, research breakthroughs, setbacks, and renewed interest. Here’s a brief overview of significant milestones in the development of AI:
#
# ### 1. **Early Concepts (1940s-1950s)**
# - **Foundational Ideas**: The concept of machines that could simulate human intelligence began to take shape in the 1940s and 1950s. Pioneers like Alan

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()

chatmodel = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7)

response = chatmodel.invoke("Tell about the history of AI")
print(response.content)
# Out:
# The history of Artificial Intelligence (AI) is a fascinating journey marked by periods of intense optimism, significant breakthroughs, and challenging "AI winters." It spans centuries of philosophical thought and decades of scientific and technological innovation.
#
# Here's a breakdown of its key eras and developments:
#
# ---
#
# ### **I. Ancient Roots & Philosophical Foundations (Pre-1940s)**
#
# The idea of artificial beings with intelligence isn't new. It appears in myths, legends, and philosophical inquiries long before computers existed:
#
# *   **Ancient Myths:** Stories of automatons, golems, and mechanical men (e.g., Talos in Greek mythology).
# *   **Formal Logic:** Philosophers like Aristotle laid the groundwork for logical reasoning, which is fundamental to AI. Later, thinkers like George Boole (Boolean logic) and Gottlob Frege developed formal systems for symbolic manipulation.
# *   **Early Calculators & Automata:** Mechanical devices like the Antikythera mechanism (ancient Greece) and later Babbage's Analytical Engine (19th century, with Ada Lovelace's insights into programming) hinted at the potential for machines to perform complex tasks.
# *   **Cybernetics (1940s):** Norbert Wiener's work on control and communication in animals and machines laid theoretical groundwork for understanding intelligent systems.
#
# ---
#
# ### **II. The Birth of AI (1940s-1950s)**
#
# The mid-20th century saw the conceptualization and initial realization of machines that could "think."
#
# *   **McCulloch & Pitts (1943):** Published a paper demonstrating how artificial neurons could perform logical functions, laying the groundwork for neural networks.
# *   **Alan Turing (1950):** Published "Computing Machinery and Intelligence," introducing the "Imitation Game" (now known as the Turing Test) as a criterion for machine intelligence and exploring the possibility of machines thinking.
# *   **Dartmouth Workshop (1956):** This pivotal summer workshop, organized by **John McCarthy**, **Marvin Minsky**, **Nathaniel Rochester**, and **Claude Shannon**, is widely considered the *birthplace of AI as a field*. McCarthy coined the term "Artificial Intelligence" for the event. The attendees were highly optimistic about machines simulating human intelligence.
#
# ---
#
# ### **III. The Golden Age of Symbolic AI & Early Optimism (1950s-1970s)**
#
# Following Dartmouth, AI research flourished, primarily focusing on symbolic reasoning and problem-solving.
#
# *   **Logic Theorist (1956):** Developed by Allen Newell, Herbert A. Simon, and J. C. Shaw, it was the first AI program, designed to mimic human problem-solving skills and prove mathematical theorems.
# *   **General Problem Solver (GPS, 1959):** Newell and Simon's attempt to create a universal problem-solving machine.
# *   **LISP (1958):** John McCarthy developed this programming language, which became the dominant language for AI research for decades due to its flexibility in handling symbolic data.
# *   **ELIZA (1966):** Joseph Weizenbaum created this early natural language processing program, which simulated a psychotherapist by recognizing keywords and rephrasing user input as questions.
# *   **Shakey the Robot (late 1960s-early 1970s):** Developed at SRI International, Shakey was the first mobile robot to reason about its own actions, plan tasks, and perceive its environment.
#
# ---
#
# ### **IV. The First AI Winter (Late 1970s - Early 1980s)**
#
# Over-ambitious promises, limited computational power, and the inherent "brittleness" of early AI systems led to disillusionment and funding cuts.
#
# *   **Lighthill Report (1973):** A critical assessment of AI research in the UK, which highlighted the lack of progress and led to significant cuts in government funding.
# *   **Limitations:** Symbolic AI systems struggled with common sense reasoning, ambiguity, and scaling to real-world complexity. They often worked well in "toy worlds" but failed in more diverse environments.
#
# ---
#
# ### **V. The Rise of Expert Systems & Second Wave (1980s)**
#
# AI experienced a resurgence with the development of expert systems.
#
# *   **Expert Systems:** These programs captured human expert knowledge in specific domains (e.g., medical diagnosis, geological exploration) using rule-based systems.
# *   **MYCIN (mid-1970s):** One of the most famous expert systems, designed to diagnose blood infections and recommend treatments.
# *   **Commercial Boom:** Companies invested heavily in expert systems, leading to a commercial boom and practical applications in various industries.
#
# ---
#
# ### **VI. The Second AI Winter (Late 1980s - Early 1990s)**
#
# The limitations of expert systems became apparent: they were expensive to build and maintain, lacked flexibility, and couldn't learn new knowledge easily.
#
# *   **Maintenance Costs:** Updating and expanding the knowledge base of expert systems proved difficult and costly.
# *   **"Brittleness":** They couldn't handle situations outside their narrow domain of expertise.
# *   **Shift in Focus:** Research began to move towards more robust, data-driven, and statistical approaches, including early forms of machine learning.
#
# ---
#
# ### **VII. Machine Learning Re-Emerges & Statistical AI (1990s - Early 2010s)**
#
# Increased computational power, availability of data, and new algorithms led to a quieter but significant revolution.
#
# *   **Neural Networks (re-emergence):** Backpropagation algorithm (developed in the 1970s and 80s) allowed for effective training of multi-layered neural networks.
# *   **Support Vector Machines (SVMs):** A powerful supervised learning model for classification and regression.
# *   **Decision Trees & Random Forests:** Popular for their interpretability and effectiveness.
# *   **Probabilistic Methods:** Bayesian networks and other statistical models gained prominence.
# *   **Deep Blue (1997):** IBM's chess-playing computer defeated world champion Garry Kasparov, showcasing the power of brute-force computation combined with sophisticated search algorithms (though not purely "learning" in the modern sense).
# *   **Data Mining:** The ability to extract patterns from large datasets became a key application.
#
# ---
#
# ### **VIII. The Deep Learning Revolution (Early 2010s - Present)**
#
# This era is characterized by monumental breakthroughs fueled by three key factors:
#
# *   **Big Data:** The explosion of digital data (images, text, speech, video) provided ample training material.
# *   **GPU Computing:** Graphics Processing Units (GPUs), originally designed for video games, proved ideal for the parallel computations required to train large neural networks.
# *   **New Architectures & Algorithms:**
#     *   **ImageNet Challenge (2012):** AlexNet, a deep convolutional neural network (CNN), achieved a breakthrough in image recognition, dramatically outperforming previous methods. This event is often cited as the spark for the deep learning boom.
#     *   **Recurrent Neural Networks (RNNs) & Long Short-Term Memory (LSTMs):** Effective for sequential data like text and speech.
#     *   **Generative Adversarial Networks (GANs, 2014):** Ian Goodfellow introduced these networks capable of generating realistic data (images, audio, video).
#     *   **Transformers (2017):** Introduced by Google Brain, this architecture revolutionized natural language processing (NLP) and formed the basis for large language models (LLMs).
#
# ---
#
# ### **IX. The Era of Generative AI & Large Language Models (Late 2010s - Present)**
#
# Deep learning has led to AI becoming mainstream and highly impactful.
#
# *   **AlphaGo (2016):** DeepMind's AI defeated the world champion of Go, Lee Sedol, a game considered far more complex than chess for AI. AlphaGo learned primarily through self-play.
# *   **Large Language Models (LLMs):**
#     *   **BERT (2018):** Google's Bidirectional Encoder Representations from Transformers significantly advanced NLP understanding.
#     *   **GPT Series (OpenAI, starting with GPT-2 in 2019, then GPT-3 in 2020, and GPT-4 in 2023):** These models demonstrated unprecedented capabilities in generating human-like text, answering questions, writing code, and more, making generative AI widely accessible and impactful.
# *   **Diffusion Models:** Powerful generative models for image and video creation (e.g., DALL-E, Midjourney, Stable Diffusion).
# *   **Multimodal AI:** AI systems that can process and generate information across different modalities (text, images, audio).
# *   **Ethical Concerns:** The rapid advancement has brought increasing scrutiny regarding bias, misinformation, job displacement, privacy, and the potential for misuse.
#
# ---
#
# ### **X. Current State & Future Outlook**
#
# AI is now integrated into countless aspects of daily life, from recommendation systems and voice assistants to medical diagnosis and scientific research.
#
# *   **Ubiquity:** AI is no longer confined to labs but is a pervasive technology.
# *   **Pursuit of AGI:** The long-term goal of Artificial General Intelligence (AGI) – machines that can perform any intellectual task a human can – remains a driving force for many researchers.
# *   **Hybrid Approaches:** Combining the strengths of symbolic AI (reasoning, knowledge representation) with connectionist AI (learning from data) is an active area of research.
# *   **Focus on Safety and Ethics:** As AI becomes more powerful, ensuring its responsible development and deployment is paramount.
#
# The history of AI is a testament to human ingenuity, marked by cycles of excitement and introspection, continually pushing the boundaries of what machines can achieve. We are currently in a period of unprecedented acceleration, with profound implications for the future.

# %%
# Using Init

from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
load_dotenv()

model = init_chat_model(
    model="gpt-4o-mini",
    model_provider="openai",

)
response = model.invoke(["Hello, how are you?"])
print(response.content)
# Out:
# Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?
